# %% [markdown]
# <a href="https://colab.research.google.com/github/taniaababneh0-ui/project-WiDS/blob/main/Amal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
